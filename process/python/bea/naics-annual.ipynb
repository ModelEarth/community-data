# %% [markdown]
# # County NAICS Files
# After running the notebook, delete the data_raw folder<br>
# Zip level not available -> https://api.census.gov/data/2011/cbp/variables.html<br>
# This notebook is a filtered and edited version of us_econ_old.ipynb for generating yearly data.<br>
# For earlier code that generates averaged data aver years please refer us_econ_old.ipynb.<br>
# This notebook will start generating data from year 2017.
# Output resides in state-naics-update. We copy manually to community-data/us/state-naics

# %%
import csv
import requests as r
import pandas as pd
import zipfile, io
import os
from tqdm import tqdm
import pathlib
import pandas as pd
import datetime
endyear = datetime.date.today().year
api_headers = {}
api_headers['x-api-key'] = '975f39a54e48438ceebf303d6018e34db212e804'

# %%
# Set a relative location to save the data from the request
repo_dir = pathlib.Path().cwd()
#print(repo_dir)

raw_data_dir = repo_dir / 'data_raw'
out_data_dir = raw_data_dir / 'BEA_Industry_Factors'
    
county_data_dir = out_data_dir / 'county_level'
if not county_data_dir.exists():
    county_data_dir.mkdir(parents=True)

# %%
# Load the state FIPS codes key
state_fips = pd.read_csv('../../../us/id_lists/state_fips.csv', usecols=['Name', 'Postal Code', 'FIPS'])
state_fips = state_fips.head(50)  # <-- limit to only US states, not teritories

# %%
# Base URL for the API call
base_url = "https://api.census.gov/data"

#
# NOTE Years Prior to 2012 Currently have a bug when specifying NAICS#### as one of the columns
#      - stick to 2012 and later for now
#

def get_county_cbp(fips, state, years):
    count = 0
    for year in years:
        print(f"Getting data for state: {state}\tyear: {year}")
        if year >= 2000 and year <= 2002:
            columns_to_select = "GEO_ID,GEO_TTL,COUNTY,YEAR,NAICS1997_TTL,ESTAB,EMP,PAYANN"
            url = f"{base_url}/{year}/cbp?get={columns_to_select}&for=county:*&in=state:{fips:02d}"
        elif year >= 2003 and year <=2007:
            columns_to_select = "GEO_ID,GEO_TTL,COUNTY,YEAR,NAICS2002_TTL,ESTAB,EMP,PAYANN"
            url = f"{base_url}/{year}/cbp?get={columns_to_select}&for=county:*&in=state:{fips:02d}"
        elif year >= 2008 and year <= 2011:
            columns_to_select = "GEO_ID,GEO_TTL,COUNTY,YEAR,NAICS2007_TTL,ESTAB,EMP,PAYANN"
            url = f"{base_url}/{year}/cbp?get={columns_to_select}&for=county:*&in=state:{fips:02d}"
        elif year >= 2012 and year <= 2016:
            columns_to_select = "GEO_ID,GEO_TTL,COUNTY,YEAR,NAICS2012,NAICS2012_TTL,ESTAB,EMP,PAYANN"
            url = f"{base_url}/{year}/cbp?get={columns_to_select}&for=county:*&in=state:{fips:02d}"
        elif year >= 2017 and year <= 2021:
            columns_to_select = "GEO_ID,NAME,COUNTY,YEAR,NAICS2017,NAICS2017_LABEL,ESTAB,EMP,PAYANN"
            url = f"{base_url}/{year}/cbp?get={columns_to_select}&for=county:*&in=state:{fips:02d}"
    
    
        response = r.get(url, headers=api_headers)

        with open(county_data_dir / f"industriesPerCounty_{str.lower(state.replace(' ', ''))}_{year}.csv",'w') as resultPath:
            for line in response.text.strip().split('\n'):
                line=line.replace('[',"").replace(']',"")
                resultPath.write(line + "\n")

        print("  > Finished CSV for year"+str(year))

# %%
#Years Initialization for data generation
startyear = 2017
endyear = 2021

# %%
for fips in state_fips.FIPS.unique():
     state = state_fips.query(f'FIPS=={fips}').values[0][0]
     years=range(startyear, endyear+1)
     get_county_cbp(fips, state, years)
# Out:
# Getting data for state: Alabama	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Alabama	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Alabama	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Alabama	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Alabama	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Alaska	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Alaska	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Alaska	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Alaska	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Alaska	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Arizona	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Arizona	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Arizona	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Arizona	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Arizona	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Arkansas	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Arkansas	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Arkansas	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Arkansas	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Arkansas	year: 2021
#   > Finished CSV for year2021
# Getting data for state: California	year: 2017
#   > Finished CSV for year2017
# Getting data for state: California	year: 2018
#   > Finished CSV for year2018
# Getting data for state: California	year: 2019
#   > Finished CSV for year2019
# Getting data for state: California	year: 2020
#   > Finished CSV for year2020
# Getting data for state: California	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Colorado	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Colorado	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Colorado	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Colorado	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Colorado	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Connecticut	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Connecticut	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Connecticut	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Connecticut	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Connecticut	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Delaware	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Delaware	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Delaware	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Delaware	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Delaware	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Florida	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Florida	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Florida	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Florida	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Florida	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Georgia	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Georgia	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Georgia	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Georgia	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Georgia	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Hawaii	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Hawaii	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Hawaii	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Hawaii	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Hawaii	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Idaho	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Idaho	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Idaho	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Idaho	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Idaho	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Illinois	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Illinois	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Illinois	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Illinois	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Illinois	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Indiana	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Indiana	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Indiana	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Indiana	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Indiana	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Iowa	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Iowa	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Iowa	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Iowa	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Iowa	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Kansas	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Kansas	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Kansas	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Kansas	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Kansas	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Kentucky	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Kentucky	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Kentucky	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Kentucky	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Kentucky	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Louisiana	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Louisiana	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Louisiana	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Louisiana	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Louisiana	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Maine	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Maine	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Maine	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Maine	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Maine	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Maryland	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Maryland	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Maryland	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Maryland	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Maryland	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Massachusetts	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Massachusetts	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Massachusetts	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Massachusetts	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Massachusetts	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Michigan	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Michigan	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Michigan	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Michigan	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Michigan	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Minnesota	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Minnesota	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Minnesota	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Minnesota	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Minnesota	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Mississippi	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Mississippi	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Mississippi	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Mississippi	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Mississippi	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Missouri	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Missouri	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Missouri	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Missouri	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Missouri	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Montana	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Montana	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Montana	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Montana	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Montana	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Nebraska	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Nebraska	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Nebraska	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Nebraska	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Nebraska	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Nevada	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Nevada	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Nevada	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Nevada	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Nevada	year: 2021
#   > Finished CSV for year2021
# Getting data for state: New Hampshire	year: 2017
#   > Finished CSV for year2017
# Getting data for state: New Hampshire	year: 2018
#   > Finished CSV for year2018
# Getting data for state: New Hampshire	year: 2019
#   > Finished CSV for year2019
# Getting data for state: New Hampshire	year: 2020
#   > Finished CSV for year2020
# Getting data for state: New Hampshire	year: 2021
#   > Finished CSV for year2021
# Getting data for state: New Jersey	year: 2017
#   > Finished CSV for year2017
# Getting data for state: New Jersey	year: 2018
#   > Finished CSV for year2018
# Getting data for state: New Jersey	year: 2019
#   > Finished CSV for year2019
# Getting data for state: New Jersey	year: 2020
#   > Finished CSV for year2020
# Getting data for state: New Jersey	year: 2021
#   > Finished CSV for year2021
# Getting data for state: New Mexico	year: 2017
#   > Finished CSV for year2017
# Getting data for state: New Mexico	year: 2018
#   > Finished CSV for year2018
# Getting data for state: New Mexico	year: 2019
#   > Finished CSV for year2019
# Getting data for state: New Mexico	year: 2020
#   > Finished CSV for year2020
# Getting data for state: New Mexico	year: 2021
#   > Finished CSV for year2021
# Getting data for state: New York	year: 2017
#   > Finished CSV for year2017
# Getting data for state: New York	year: 2018
#   > Finished CSV for year2018
# Getting data for state: New York	year: 2019
#   > Finished CSV for year2019
# Getting data for state: New York	year: 2020
#   > Finished CSV for year2020
# Getting data for state: New York	year: 2021
#   > Finished CSV for year2021
# Getting data for state: North Carolina	year: 2017
#   > Finished CSV for year2017
# Getting data for state: North Carolina	year: 2018
#   > Finished CSV for year2018
# Getting data for state: North Carolina	year: 2019
#   > Finished CSV for year2019
# Getting data for state: North Carolina	year: 2020
#   > Finished CSV for year2020
# Getting data for state: North Carolina	year: 2021
#   > Finished CSV for year2021
# Getting data for state: North Dakota	year: 2017
#   > Finished CSV for year2017
# Getting data for state: North Dakota	year: 2018
#   > Finished CSV for year2018
# Getting data for state: North Dakota	year: 2019
#   > Finished CSV for year2019
# Getting data for state: North Dakota	year: 2020
#   > Finished CSV for year2020
# Getting data for state: North Dakota	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Ohio	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Ohio	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Ohio	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Ohio	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Ohio	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Oklahoma	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Oklahoma	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Oklahoma	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Oklahoma	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Oklahoma	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Oregon	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Oregon	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Oregon	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Oregon	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Oregon	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Pennsylvania	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Pennsylvania	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Pennsylvania	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Pennsylvania	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Pennsylvania	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Rhode Island	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Rhode Island	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Rhode Island	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Rhode Island	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Rhode Island	year: 2021
#   > Finished CSV for year2021
# Getting data for state: South Carolina	year: 2017
#   > Finished CSV for year2017
# Getting data for state: South Carolina	year: 2018
#   > Finished CSV for year2018
# Getting data for state: South Carolina	year: 2019
#   > Finished CSV for year2019
# Getting data for state: South Carolina	year: 2020
#   > Finished CSV for year2020
# Getting data for state: South Carolina	year: 2021
#   > Finished CSV for year2021
# Getting data for state: South Dakota	year: 2017
#   > Finished CSV for year2017
# Getting data for state: South Dakota	year: 2018
#   > Finished CSV for year2018
# Getting data for state: South Dakota	year: 2019
#   > Finished CSV for year2019
# Getting data for state: South Dakota	year: 2020
#   > Finished CSV for year2020
# Getting data for state: South Dakota	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Tennessee	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Tennessee	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Tennessee	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Tennessee	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Tennessee	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Texas	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Texas	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Texas	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Texas	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Texas	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Utah	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Utah	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Utah	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Utah	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Utah	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Vermont	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Vermont	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Vermont	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Vermont	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Vermont	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Virginia	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Virginia	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Virginia	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Virginia	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Virginia	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Washington	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Washington	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Washington	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Washington	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Washington	year: 2021
#   > Finished CSV for year2021
# Getting data for state: West Virginia	year: 2017
#   > Finished CSV for year2017
# Getting data for state: West Virginia	year: 2018
#   > Finished CSV for year2018
# Getting data for state: West Virginia	year: 2019
#   > Finished CSV for year2019
# Getting data for state: West Virginia	year: 2020
#   > Finished CSV for year2020
# Getting data for state: West Virginia	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Wisconsin	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Wisconsin	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Wisconsin	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Wisconsin	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Wisconsin	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Wyoming	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Wyoming	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Wyoming	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Wyoming	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Wyoming	year: 2021
#   > Finished CSV for year2021

# %% [markdown]
# # Data Aggregation
# This part allows us to manage different Fips level (county/state) and different NAICS level (sector/industry/etc...)
# Trick: Getting the NAICS code from all the NAICS files that we downloaded

# %%
# Load the data from startyear

def load_all_states(bea_data_dir):
    
    for i in range(startyear,endyear+1):

        x="_"+str(i)
        files = [f for f in bea_data_dir.iterdir() if x in f.name]

        for f in files:

            # variable selection based on census year
            naics_str = "NAICS2012" if i < 2017 else "NAICS2017"
            naics_ttl = "NAICS2012_TTL" if i < 2017 else "NAICS2017_LABEL"
            geo_ttl = "GEO_TTL" if i < 2017 else "NAME"

            df = pd.read_csv(f,encoding='latin-1',dtype={naics_str: str})
            if 'Unnamed: 11' in df.columns:
                df=df.drop("Unnamed: 11", axis=1)
            if 'Unnamed: 10' in df.columns:
                df=df.drop("Unnamed: 10", axis=1)

            # renaming columns so similar data from 2012 census & 2017 census are entered into appropriate columns
            df = df.rename(columns={"fips": "id", naics_str: "relevant_naics","EMP":"emp","PAYANN":"payann","ESTAB":"estab", naics_ttl:"NAICS_TTL", geo_ttl:"GEO_TTL"})
            naics_str = "relevant_naics"
            naics_ttl = "NAICS_TTL"
            geo_ttl = "GEO_TTL"

            df['is5'] = df[naics_str].apply(lambda x: 'True' if len(x) == 5 else 'False')

            df.loc[(df['is5'] == 'True') & (df[naics_str].apply(lambda v: v[2:3]) == '-'), 'NAICS_Sector'] = df[naics_str]
            df.loc[(df['is5'] == 'True') & (df[naics_str].apply(lambda v: v[2:3]) != '-'), 'NAICS_Sector'] = df[naics_str].apply(lambda v: v[:2])
            df.loc[(df['is5'] == 'False') , 'NAICS_Sector'] = df[naics_str].apply(lambda v: v[:2])

            yield df
    
df = pd.concat(load_all_states(county_data_dir)).drop("is5", axis=1)

#df

# %%
df=df.drop("county", axis=1)

# %% [markdown]
# ### Process FIPS Code
# FIPS is the federal/census unique ID for each geographic area.  States have 2 digives and counties have 5

# %%
# Process FIPS code
df['fips'] = df.GEO_ID.apply(lambda GID: GID.split('US')[1])

def county_level(df):
    return df[df['id'].str.len() == 5]

def state_level(df):
    return df[df['id'].str.len() == 2]

# %%
# NOTE If this block is run please delete the generated file before pushing into repo (file size too large)
#df.to_csv("allll.csv")

# %% [markdown]
# ### Renaming Columns for aggregate df
# Note that we are no longer averaging data for all years. That remains in the original us_econ_old notebook

# %%
newDF = df.rename(columns={"fips": "id","EMP":"emp","PAYANN":"payann","ESTAB":"estab"})
newDF
# Out:
#               GEO_ID                    GEO_TTL  COUNTY  YEAR relevant_naics  \
# 0     0500000US51127  New Kent County, Virginia     127  2017         237310
# 1     0500000US51127  New Kent County, Virginia     127  2017            238
# 2     0500000US51127  New Kent County, Virginia     127  2017           2381
# 3     0500000US51127  New Kent County, Virginia     127  2017          23814
# 4     0500000US51127  New Kent County, Virginia     127  2017         238140
# ...              ...                        ...     ...   ...            ...
# 2922  0500000US10005    Sussex County, Delaware       5  2021          81393
# 2923  0500000US10005    Sussex County, Delaware       5  2021         813930
# 2924  0500000US10005    Sussex County, Delaware       5  2021          81399
# 2925  0500000US10005    Sussex County, Delaware       5  2021         813990
# 2926  0500000US10005    Sussex County, Delaware       5  2021             99
#
#                                               NAICS_TTL  estab  emp  payann  \
# 0              Highway, street, and bridge construction      4   47    4387
# 1                           Specialty trade contractors     58  295   15102
# 2     Foundation, structure, and building exterior c...     12   79    6415
# 3                                   Masonry contractors      6   24    1010
# 4                                   Masonry contractors      6   24    1010
# ...                                                 ...    ...  ...     ...
# 2922       Labor unions and similar labor organizations      3    8      72
# 2923       Labor unions and similar labor organizations      3    8      72
# 2924  Other similar organizations (except business, ...     20   58    2657
# 2925  Other similar organizations (except business, ...     20   58    2657
# 2926                          Industries not classified     51   52     986
#
#       state NAICS_Sector     id
# 0        51           23  51127
# 1        51           23  51127
# 2        51           23  51127
# 3        51           23  51127
# 4        51           23  51127
# ...     ...          ...    ...
# 2922     10           81  10005
# 2923     10           81  10005
# 2924     10           81  10005
# 2925     10           81  10005
# 2926     10           99  10005
#
# [5384060 rows x 12 columns]

# %%
newDF.tail(50)
# Out:
#               GEO_ID                  GEO_TTL  COUNTY  YEAR relevant_naics  \
# 2877  0500000US10005  Sussex County, Delaware       5  2021          81141
# 2878  0500000US10005  Sussex County, Delaware       5  2021         811412
# 2906     10           81  10005
# 2907     10           81  10005
# 2908     10           81  10005
# 2909     10           81  10005
# 2910     10           81  10005
# 2911     10           81  10005
# 2912     10           81  10005
# 2913     10           81  10005
# 2914     10           81  10005
# 2915     10           81  10005
# 2916     10           81  10005
# 2917     10           81  10005
# 2918     10           81  10005
# 2919     10           81  10005
# 2920     10           81  10005
# 2921     10           81  10005
# 2922     10           81  10005
# 2923     10           81  10005
# 2924     10           81  10005
# 2925     10           81  10005
# 2926     10           99  10005

# %% [markdown]
# ### Group data by NAICS Sector
#
# NAICS is the North American Industry Classification System. The coarsest level of classification is the *Sector*.
#
# The organization of NAICS is as follows:  <-- from [this page](https://www.census.gov/programs-surveys/economic-census/guidance/understanding-naics.html) on census.gov
# - Sector: 2-digit code
#     - Subsector: 3-digit code
#         - Industry Group: 4-digit code
#             - NAICS Industry: 5-digit code
#                 - National Industry: 6-digit code
#
# Start by grouping the data by sector:

# %%
def naics_level(df, naics_level):
    return df[df['relevant_naics'].str.len() == naics_level]

# %%
df_naics_2 = naics_level(newDF, 2).reset_index(drop=True)
df_naics_3 = naics_level(newDF, 3).reset_index(drop=True)
df_naics_4 = naics_level(newDF, 4).reset_index(drop=True)
df_naics_5 = naics_level(newDF, 5).reset_index(drop=True)
df_naics_6 = naics_level(newDF, 6).reset_index(drop=True)

df_naics_2 = df_naics_2[df_naics_2.relevant_naics != '00']
df_naics_3 = df_naics_3[df_naics_3.relevant_naics != '00']
df_naics_4 = df_naics_4[df_naics_4.relevant_naics != '00']
df_naics_5 = df_naics_5[df_naics_5.relevant_naics != '00']
df_naics_6 = df_naics_6[df_naics_6.relevant_naics != '00']

# %%
#s2=state_level(df_naics_2)
c2=county_level(df_naics_2)
#s3=state_level(df_naics_3)
#c3=county_level(df_naics_3)
#s4=state_level(df_naics_4)
c4=county_level(df_naics_4)
#s5=state_level(df_naics_5)
#c5=county_level(df_naics_5)
s6=state_level(df_naics_6)
#c6=county_level(df_naics_6)

# %%
newDF
# Out:
#               GEO_ID                    GEO_TTL  COUNTY  YEAR relevant_naics  \
# 0     0500000US51127  New Kent County, Virginia     127  2017         237310
# 1     0500000US51127  New Kent County, Virginia     127  2017            238
# 2     0500000US51127  New Kent County, Virginia     127  2017           2381
# 3     0500000US51127  New Kent County, Virginia     127  2017          23814
# 4     0500000US51127  New Kent County, Virginia     127  2017         238140
# ...              ...                        ...     ...   ...            ...
# 2922  0500000US10005    Sussex County, Delaware       5  2021          81393
# 2923  0500000US10005    Sussex County, Delaware       5  2021         813930
# 2924  0500000US10005    Sussex County, Delaware       5  2021          81399
# 2925  0500000US10005    Sussex County, Delaware       5  2021         813990
# 2926  0500000US10005    Sussex County, Delaware       5  2021             99
#
#                                               NAICS_TTL  estab  emp  payann  \
# 0              Highway, street, and bridge construction      4   47    4387
# 1                           Specialty trade contractors     58  295   15102
# 2     Foundation, structure, and building exterior c...     12   79    6415
# 3                                   Masonry contractors      6   24    1010
# 4                                   Masonry contractors      6   24    1010
# ...                                                 ...    ...  ...     ...
# 2922       Labor unions and similar labor organizations      3    8      72
# 2923       Labor unions and similar labor organizations      3    8      72
# 2924  Other similar organizations (except business, ...     20   58    2657
# 2925  Other similar organizations (except business, ...     20   58    2657
# 2926                          Industries not classified     51   52     986
#
#       state NAICS_Sector     id
# 0        51           23  51127
# 1        51           23  51127
# 2        51           23  51127
# 3        51           23  51127
# 4        51           23  51127
# ...     ...          ...    ...
# 2922     10           81  10005
# 2923     10           81  10005
# 2924     10           81  10005
# 2925     10           81  10005
# 2926     10           99  10005
#
# [5384060 rows x 12 columns]

# %% [markdown]
# Skipped the code block for `The statewide data does not include NAICS starting with 1!` from us_econ nb

# %% [markdown]
# # NAICS code to name translation
# Using 2012 naics codes and industries since 2017 naics codes & industries are not available in the current crosswalks data.<br>
# TODO: Update the 2012 codes with 2017 codes for updated data

# %%
NAICS_codes = pd.read_csv('../../../us/Crosswalk_MasterCrosswalk.csv', usecols=['2012_NAICS_Code', '2012_NAICS_Industry'])

# %%
NAICS_codes=NAICS_codes.rename(columns={"2012_NAICS_Code": "relevant_naics", "2012_NAICS_Industry": "industry_detail"})

# %%
NAICS_codes=NAICS_codes.dropna()

# %%
NAICS_codes=NAICS_codes.drop_duplicates()

# %%
NAICS_codes
# Out:
#       relevant_naics                               industry_detail
# 0               11.0    Agriculture, Forestry, Fishing and Hunting
# 13             111.0                               Crop Production
# 19            1111.0                     Oilseed and Grain Farming
# 21           11111.0                               Soybean Farming
# 22          111110.0                               Soybean Farming
# ...              ...                                           ...
# 3885          9281.0  National Security and International Affairs
# 3887         92811.0                            National Security
# 3888        928110.0                            National Security
# 3889         92812.0                        International Affairs
# 3890        928120.0                        International Affairs
#
# [2214 rows x 2 columns]

# %%
#adding the row for Industries not classified
NAICS_codes
new_row = {'relevant_naics':99, 'industry_detail':"Industries not classified"}

#append row to the dataframe
NAICS_codes = pd.concat([NAICS_codes, pd.DataFrame([new_row])], ignore_index=True)

# %%
NAICS_codes
# Out:
#       relevant_naics                             industry_detail
# 0               11.0  Agriculture, Forestry, Fishing and Hunting
# 1              111.0                             Crop Production
# 2             1111.0                   Oilseed and Grain Farming
# 3            11111.0                             Soybean Farming
# 4           111110.0                             Soybean Farming
# ...              ...                                         ...
# 2210         92811.0                          National Security
# 2211        928110.0                          National Security
# 2212         92812.0                      International Affairs
# 2213        928120.0                      International Affairs
# 2214            99.0                   Industries not classified
#
# [2215 rows x 2 columns]

# %%
NAICS_codes.to_csv('../../../us/id_lists/industry_ID_list.csv')

# %% [markdown]
# # Making a states json

# %%
stateFips = pd.read_csv('../../../us/id_lists/state_fips.csv')

# %%
stateFips=stateFips.drop(['Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6'],axis=1)

# %%
stateFips
# Out:
#                         Name Postal Code  FIPS
# 0                    Alabama          AL     1
# 1                     Alaska          AK     2
# 2                    Arizona          AZ     4
# 3                   Arkansas          AR     5
# 4                 California          CA     6
# 5                   Colorado          CO     8
# 6                Connecticut          CT     9
# 7                   Delaware          DE    10
# 8                    Florida          FL    12
# 9                    Georgia          GA    13
# 10                    Hawaii          HI    15
# 11                     Idaho          ID    16
# 12                  Illinois          IL    17
# 13                   Indiana          IN    18
# 14                      Iowa          IA    19
# 15                    Kansas          KS    20
# 16                  Kentucky          KY    21
# 17                 Louisiana          LA    22
# 18                     Maine          ME    23
# 19                  Maryland          MD    24
# 20             Massachusetts          MA    25
# 21                  Michigan          MI    26
# 22                 Minnesota          MN    27
# 23               Mississippi          MS    28
# 24                  Missouri          MO    29
# 25                   Montana          MT    30
# 26                  Nebraska          NE    31
# 27                    Nevada          NV    32
# 28             New Hampshire          NH    33
# 29                New Jersey          NJ    34
# 30                New Mexico          NM    35
# 31                  New York          NY    36
# 32            North Carolina          NC    37
# 33              North Dakota          ND    38
# 34                      Ohio          OH    39
# 35                  Oklahoma          OK    40
# 36                    Oregon          OR    41
# 37              Pennsylvania          PA    42
# 38              Rhode Island          RI    44
# 39            South Carolina          SC    45
# 40              South Dakota          SD    46
# 41                 Tennessee          TN    47
# 42                     Texas          TX    48
# 43                      Utah          UT    49
# 44                   Vermont          VT    50
# 45                  Virginia          VA    51
# 46                Washington          WA    53
# 47             West Virginia          WV    54
# 48                 Wisconsin          WI    55
# 49                   Wyoming          WY    56
# 50            American Samoa          AS    60
# 51                      Guam          GU    66
# 52  Northern Mariana Islands          MP    69
# 53               Puerto Rico          PR    72
# 54            Virgin Islands          VI    78

# %%
#stateFips.to_json(county_data_dir/'states.json', orient = "records", date_format = "epoch", double_precision = 10, force_ascii = True, date_unit = "ms", default_handler = None)

# %% [markdown]
# # Making county to fips csv

# %%
countyDF=c2[['GEO_TTL','id']].drop_duplicates()

# %%
countyDF
# Out:
#                               GEO_TTL     id
# 0           New Kent County, Virginia  51127
# 15           Augusta County, Virginia  51015
# 32        Cumberland County, Virginia  51049
# 42         Dickenson County, Virginia  51051
# 54         Goochland County, Virginia  51075
# ...                               ...    ...
# 57725   Issaquena County, Mississippi  28055
# 94424         Arthur County, Nebraska  31005
# 118819            Clark County, Idaho  16033
# 156687           Loving County, Texas  48301
# 176378          Loup County, Nebraska  31115
#
# [3134 rows x 2 columns]

# %%
countyDF['hascomma'] = countyDF['GEO_TTL'].apply(lambda x: 'True' if ',' in x else 'False')
countyDF
# Out:
#                               GEO_TTL     id hascomma
# 0           New Kent County, Virginia  51127     True
# 15           Augusta County, Virginia  51015     True
# 32        Cumberland County, Virginia  51049     True
# 42         Dickenson County, Virginia  51051     True
# 54         Goochland County, Virginia  51075     True
# ...                               ...    ...      ...
# 57725   Issaquena County, Mississippi  28055     True
# 94424         Arthur County, Nebraska  31005     True
# 118819            Clark County, Idaho  16033     True
# 156687           Loving County, Texas  48301     True
# 176378          Loup County, Nebraska  31115     True
#
# [3134 rows x 3 columns]

# %%
countyDF.loc[(countyDF['hascomma'] == 'True'), 'county'] = countyDF.GEO_TTL.apply(lambda GTT: GTT.split(', ')[0])
countyDF.loc[(countyDF['hascomma'] == 'True'), 'state'] = countyDF.GEO_TTL.apply(lambda GTT: GTT.split(', ')[-1])

# %%
countyDF=countyDF[['state','county','id']].drop_duplicates()

# %%
countyDF = countyDF.dropna()

# %%
countyDF
# Out:
#               state             county     id
# 0          Virginia    New Kent County  51127
# 15         Virginia     Augusta County  51015
# 32         Virginia  Cumberland County  51049
# 42         Virginia   Dickenson County  51051
# 54         Virginia   Goochland County  51075
# ...             ...                ...    ...
# 57725   Mississippi   Issaquena County  28055
# 94424      Nebraska      Arthur County  31005
# 118819        Idaho       Clark County  16033
# 156687        Texas      Loving County  48301
# 176378     Nebraska        Loup County  31115
#
# [3134 rows x 3 columns]

# %%
stats = stateFips.rename(columns={"Name": "state"})

# %%
stats = stats.drop("FIPS",axis=1)
stats
# Out:
#                        state Postal Code
# 0                    Alabama          AL
# 1                     Alaska          AK
# 2                    Arizona          AZ
# 3                   Arkansas          AR
# 4                 California          CA
# 5                   Colorado          CO
# 6                Connecticut          CT
# 7                   Delaware          DE
# 8                    Florida          FL
# 9                    Georgia          GA
# 10                    Hawaii          HI
# 11                     Idaho          ID
# 12                  Illinois          IL
# 13                   Indiana          IN
# 14                      Iowa          IA
# 15                    Kansas          KS
# 16                  Kentucky          KY
# 17                 Louisiana          LA
# 18                     Maine          ME
# 19                  Maryland          MD
# 20             Massachusetts          MA
# 21                  Michigan          MI
# 22                 Minnesota          MN
# 23               Mississippi          MS
# 24                  Missouri          MO
# 25                   Montana          MT
# 26                  Nebraska          NE
# 27                    Nevada          NV
# 28             New Hampshire          NH
# 29                New Jersey          NJ
# 30                New Mexico          NM
# 31                  New York          NY
# 32            North Carolina          NC
# 33              North Dakota          ND
# 34                      Ohio          OH
# 35                  Oklahoma          OK
# 36                    Oregon          OR
# 37              Pennsylvania          PA
# 38              Rhode Island          RI
# 39            South Carolina          SC
# 40              South Dakota          SD
# 41                 Tennessee          TN
# 42                     Texas          TX
# 43                      Utah          UT
# 44                   Vermont          VT
# 45                  Virginia          VA
# 46                Washington          WA
# 47             West Virginia          WV
# 48                 Wisconsin          WI
# 49                   Wyoming          WY
# 50            American Samoa          AS
# 51                      Guam          GU
# 52  Northern Mariana Islands          MP
# 53               Puerto Rico          PR
# 54            Virgin Islands          VI

# %%
countyDF = countyDF.merge(stats, on='state', how='left')

# %%
countyDF = countyDF.rename(columns={"Postal Code": "abvr"})
countyDF
# Out:
#             state             county     id abvr
# 0        Virginia    New Kent County  51127   VA
# 1        Virginia     Augusta County  51015   VA
# 2        Virginia  Cumberland County  51049   VA
# 3        Virginia   Dickenson County  51051   VA
# 4        Virginia   Goochland County  51075   VA
# ...           ...                ...    ...  ...
# 3129  Mississippi   Issaquena County  28055   MS
# 3130     Nebraska      Arthur County  31005   NE
# 3131        Idaho       Clark County  16033   ID
# 3132        Texas      Loving County  48301   TX
# 3133     Nebraska        Loup County  31115   NE
#
# [3134 rows x 4 columns]

# %% [markdown]
# # Saving the County level data

# %%
#NOTE Code block to generate individual county level files for each county. (Commented because no need of each county files)
# states = newDF.state.unique()
# #states=[13]

# df_naics_6 = df_naics_6.astype({'relevant_naics': 'string'})

# a = county_level(df_naics_2)
# b = county_level(df_naics_4)
# c = county_level(df_naics_6)

# for state in states:
#     stateName = stateFips.loc[stateFips.FIPS==state,"Postal Code"].values[0]
#     print(stateName)

#     repo_dir = pathlib.Path().cwd()
#     state_dir = repo_dir.parents[2] / 'industries' / 'naics' / 'US' / 'counties-update' / stateName
    
#     if not state_dir.exists():
#         state_dir.mkdir(parents=True)
    
#     a1 = a[a.state==state]
#     b1 = b[b.state==state]
#     c1 = c[c.state==state]

#     for year in range(startyear, endyear+1):
#         print(year)

#         a1y = a1[a1.YEAR==year]
#         b1y = b1[b1.YEAR==year]
#         c1y = c1[c1.YEAR==year]

#         def save_county_data(state, df, counties, naics_level_str):
#             for county in counties:

#                 curr_df = df[df.COUNTY==county]
                
#                 county = str(county)
#                 # print(county)
#                 if len(county) == 2:
#                     county = "0" + county
#                 elif len(county) == 1:
#                     county = "00" + county

#                 state = str(state) if len(str(state)) == 2 else "0" + str(state)

#                 curr_df = curr_df.drop(["GEO_ID", "GEO_TTL", "COUNTY", "YEAR", "NAICS_TTL", "state", "NAICS_Sector"], axis=1)
#                 curr_df = curr_df.rename(columns={"id":"fips"})

#                 filename = "US" + state + county + "-" + "census-" + naics_level_str + "-" + str(year) + ".csv"

#                 curr_df.to_csv(f"../../../industries/naics/US/counties-update/state-naics-update/{stateName}/{filename}")

#         c_a1 = a1.COUNTY.unique()
#         c_b1 = b1.COUNTY.unique()
#         c_c1 = c1.COUNTY.unique()

#         save_county_data(state, a1y, c_a1, "naics2")
#         save_county_data(state, b1y, c_b1, "naics4")
#         save_county_data(state, c1y, c_c1, "naics6")

# %%
states = newDF.state.unique()
#states=[13]

df_naics_6 = df_naics_6.astype({'relevant_naics': 'string'})

a = county_level(df_naics_2)
b = county_level(df_naics_4)
c = county_level(df_naics_6)

for state in states:
    stateName = stateFips.loc[stateFips.FIPS==state,"Postal Code"].values[0]
    print(stateName)

    repo_dir = pathlib.Path().cwd()
    # state_dir = repo_dir.parents[2] / 'us' / 'state-naics-update' / stateName
    state_dir = repo_dir.parents[2] / 'industries' / 'naics' / 'US' / 'counties-update' / stateName

    
    if not state_dir.exists():
        state_dir.mkdir(parents=True)
    
    a1 = a[a.state==state]
    b1 = b[b.state==state]
    c1 = c[c.state==state]

    for year in range(startyear, endyear+1):
        print(year)

        a1y = a1[a1.YEAR==year]
        b1y = b1[b1.YEAR==year]
        c1y = c1[c1.YEAR==year]

        def save_county_data(state, df, naics_level_str):

            state = str(state) if len(str(state)) == 2 else "0" + str(state)

            curr_df = df.drop(["GEO_ID", "GEO_TTL", "COUNTY", "YEAR", "NAICS_TTL", "state", "NAICS_Sector"], axis=1)
            curr_df = curr_df.rename(columns={"id":"Fips", "relevant_naics":"Naics", "estab":"Establishments", "emp":"Employees", "payann":"Payroll"})
            curr_df = curr_df[["Fips", "Naics", "Establishments", "Employees", "Payroll"]]

            filename = "US-" + stateName + "-" + "census-" + naics_level_str + "-counties-" + str(year) + ".csv"

# HI
# 2017
# 2018
# 2019
# 2020
# 2021
# FL
# 2017
# 2018
# 2019
# 2020
# 2021

# %% [markdown]
# # saving the statewide data
# Comment & uncomment the following code block with caution

# %%
#NOTE: Activate this cell only if you want to generate state naics data USING county cbp api (NOT the state cbp api)
#NOTE: If this block is activated, comment the data generation block for state naics which is using state cbp api request directly

# states=newDF.state.unique()
# #states=[13]

# for state in states:
    
#     b1 = county_level(df_naics_2)
#     c1 = b1[b1.state==state]
#     c1.astype({'NAICS_Sector': 'int'})
#     d1 = c1.groupby(['NAICS_Sector','NAICS_TTL','state','relevant_naics', "YEAR"],as_index=False).sum()
#     d1 = d1.drop(["COUNTY","id", "GEO_TTL", "NAICS_Sector", "NAICS_TTL", "state", "GEO_ID"],axis=1)
#     # d1.insert(0, 'Fips', state)
#     # d1.insert(1, 'COUNTY', 999)
#     # d1.insert(2, 'GEO_TTL', 'Statewide')

#     b2 = county_level(df_naics_4)
#     c2 = b2[b2.state==state]
#     c2.astype({'NAICS_Sector': 'int'})
#     d2 = c2.groupby(['NAICS_Sector','NAICS_TTL','state','relevant_naics', "YEAR"],as_index=False).sum()
#     d2 = d2.drop(["COUNTY","id", "GEO_TTL", "NAICS_Sector", "NAICS_TTL", "state", "GEO_ID"],axis=1)
#     # d2.insert(0, 'Fips', state)
#     # d2.insert(1, 'COUNTY', 999)
#     # d2.insert(2, 'GEO_TTL', 'Statewide')

#     b3 = county_level(df_naics_6)
#     c3 = b3[b3.state==state]
#     c3.astype({'NAICS_Sector': 'int'})
#     d3 = c3.groupby(['NAICS_Sector','NAICS_TTL','state','relevant_naics', "YEAR"],as_index=False).sum()
#     d3 = d3.drop(["COUNTY","id", "GEO_TTL", "NAICS_Sector", "NAICS_TTL", "state", "GEO_ID"],axis=1)
#     # d3.insert(0, 'Fips', state)
#     # d3.insert(1, 'COUNTY', 999)
#     # d3.insert(2, 'GEO_TTL', 'Statewide')
    
#     stateName=stateFips.loc[stateFips.FIPS==state,"Postal Code"].values[0]
#     print(stateName)

#     for year in range(startyear, endyear+1):
#         print(year)

#         def save_state_data(state, df, naics_level_str):
                
#             state = str(state) if len(str(state)) == 2 else "0" + str(state)

#             filename = "US-" + stateName + "-" + "census-" + naics_level_str + "-" + str(year) + ".csv"

#             curr_df = df.rename(columns={"relevant_naics":"Naics", "estab":"Establishments", "emp":"Employees", "payann":"Payroll"})

#             curr_df.to_csv(f"../../../industries/naics/US/counties-update/{stateName}/{filename}", index=False)

#         d1y = d1[d1.YEAR==year]
#         d2y = d2[d2.YEAR==year]
#         d3y = d3[d3.YEAR==year]

#         d1y = d1y.drop(["YEAR"],axis=1)
#         d2y = d2y.drop(["YEAR"],axis=1)
#         d3y = d3y.drop(["YEAR"],axis=1)

#         save_state_data(state, d1y, "naics2")
#         save_state_data(state, d2y, "naics4")
#         save_state_data(state, d3y, "naics6")
# Out:
# VA
# 2017
# 2018
# 2019
# 2020
# 2021
# KS
# 2017
# 2018
# 2019
# 2020
# 2021
# AR
# 2017

            columns_to_select = "GEO_ID,GEO_TTL,COUNTY,YEAR,NAICS1997_TTL,ESTAB,EMP,PAYANN"
            url=f"{base_url}/{year}/cbp?get={columns_to_select}&for=state:{fips:02d}"
        elif year>=2003 and year<=2007:
            columns_to_select = "GEO_ID,GEO_TTL,COUNTY,YEAR,NAICS2002_TTL,ESTAB,EMP,PAYANN"
            url=f"{base_url}/{year}/cbp?get={columns_to_select}&for=state:{fips:02d}"
        elif year>=2008 and year<=2011:
            columns_to_select = "GEO_ID,GEO_TTL,COUNTY,YEAR,NAICS2007_TTL,ESTAB,EMP,PAYANN"
            url=f"{base_url}/{year}/cbp?get={columns_to_select}&for=state:{fips:02d}"
        elif year>=2012 and year<=2016:
            columns_to_select = "GEO_ID,GEO_TTL,COUNTY,YEAR,NAICS2012,NAICS2012_TTL,ESTAB,EMP,PAYANN"
            url=f"{base_url}/{year}/cbp?get={columns_to_select}&for=state:{fips:02d}"
        elif year>=2017 and year <= 2021:
            columns_to_select = "GEO_ID,NAME,COUNTY,YEAR,NAICS2017,NAICS2017_LABEL,ESTAB,EMP,PAYANN"
            url=f"{base_url}/{year}/cbp?get={columns_to_select}&for=state:{fips:02d}"
    
    
        response = r.get(url, headers=api_headers)

        with open(state_data_dir / f"industriesPerState_{str.lower(state.replace(' ', ''))}_{year}.csv",'w') as resultPath:
            for line in response.text.strip().split('\n'):
                line=line.replace('[',"").replace(']',"")
                resultPath.write(line + "\n")

        print("  > Finished CSV for year"+str(year))

# %%
for fips in state_fips.FIPS.unique():
     state = state_fips.query(f'FIPS=={fips}').values[0][0]
     years=range(startyear,endyear+1)
     get_state_cbp(fips, state, years)
# Out:
# Getting data for state: Alabama	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Alabama	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Alabama	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Alabama	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Alabama	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Alaska	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Alaska	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Alaska	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Alaska	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Alaska	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Arizona	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Arizona	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Arizona	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Arizona	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Arizona	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Arkansas	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Arkansas	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Arkansas	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Arkansas	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Arkansas	year: 2021
#   > Finished CSV for year2021
# Getting data for state: California	year: 2017
#   > Finished CSV for year2017
# Getting data for state: California	year: 2018
#   > Finished CSV for year2018
# Getting data for state: California	year: 2019
#   > Finished CSV for year2019
# Getting data for state: California	year: 2020
#   > Finished CSV for year2020
# Getting data for state: California	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Colorado	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Colorado	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Colorado	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Colorado	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Colorado	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Connecticut	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Connecticut	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Connecticut	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Connecticut	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Connecticut	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Delaware	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Delaware	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Delaware	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Delaware	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Delaware	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Florida	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Florida	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Florida	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Florida	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Florida	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Georgia	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Georgia	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Georgia	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Georgia	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Georgia	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Hawaii	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Hawaii	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Hawaii	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Hawaii	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Hawaii	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Idaho	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Idaho	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Idaho	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Idaho	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Idaho	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Illinois	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Illinois	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Illinois	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Illinois	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Illinois	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Indiana	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Indiana	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Indiana	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Indiana	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Indiana	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Iowa	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Iowa	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Iowa	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Iowa	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Iowa	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Kansas	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Kansas	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Kansas	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Kansas	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Kansas	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Kentucky	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Kentucky	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Kentucky	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Kentucky	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Kentucky	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Louisiana	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Louisiana	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Louisiana	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Louisiana	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Louisiana	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Maine	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Maine	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Maine	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Maine	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Maine	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Maryland	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Maryland	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Maryland	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Maryland	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Maryland	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Massachusetts	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Massachusetts	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Massachusetts	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Massachusetts	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Massachusetts	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Michigan	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Michigan	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Michigan	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Michigan	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Michigan	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Minnesota	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Minnesota	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Minnesota	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Minnesota	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Minnesota	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Mississippi	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Mississippi	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Mississippi	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Mississippi	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Mississippi	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Missouri	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Missouri	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Missouri	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Missouri	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Missouri	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Montana	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Montana	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Montana	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Montana	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Montana	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Nebraska	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Nebraska	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Nebraska	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Nebraska	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Nebraska	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Nevada	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Nevada	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Nevada	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Nevada	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Nevada	year: 2021
#   > Finished CSV for year2021
# Getting data for state: New Hampshire	year: 2017
#   > Finished CSV for year2017
# Getting data for state: New Hampshire	year: 2018
#   > Finished CSV for year2018
# Getting data for state: New Hampshire	year: 2019
#   > Finished CSV for year2019
# Getting data for state: New Hampshire	year: 2020
#   > Finished CSV for year2020
# Getting data for state: New Hampshire	year: 2021
#   > Finished CSV for year2021
# Getting data for state: New Jersey	year: 2017
#   > Finished CSV for year2017
# Getting data for state: New Jersey	year: 2018
#   > Finished CSV for year2018
# Getting data for state: New Jersey	year: 2019
#   > Finished CSV for year2019
# Getting data for state: New Jersey	year: 2020
#   > Finished CSV for year2020
# Getting data for state: New Jersey	year: 2021
#   > Finished CSV for year2021
# Getting data for state: New Mexico	year: 2017
#   > Finished CSV for year2017
# Getting data for state: New Mexico	year: 2018
#   > Finished CSV for year2018
# Getting data for state: New Mexico	year: 2019
#   > Finished CSV for year2019
# Getting data for state: New Mexico	year: 2020
#   > Finished CSV for year2020
# Getting data for state: New Mexico	year: 2021
#   > Finished CSV for year2021
# Getting data for state: New York	year: 2017
#   > Finished CSV for year2017
# Getting data for state: New York	year: 2018
#   > Finished CSV for year2018
# Getting data for state: New York	year: 2019
#   > Finished CSV for year2019
# Getting data for state: New York	year: 2020
#   > Finished CSV for year2020
# Getting data for state: New York	year: 2021
#   > Finished CSV for year2021
# Getting data for state: North Carolina	year: 2017
#   > Finished CSV for year2017
# Getting data for state: North Carolina	year: 2018
#   > Finished CSV for year2018
# Getting data for state: North Carolina	year: 2019
#   > Finished CSV for year2019
# Getting data for state: North Carolina	year: 2020
#   > Finished CSV for year2020
# Getting data for state: North Carolina	year: 2021
#   > Finished CSV for year2021
# Getting data for state: North Dakota	year: 2017
#   > Finished CSV for year2017
# Getting data for state: North Dakota	year: 2018
#   > Finished CSV for year2018
# Getting data for state: North Dakota	year: 2019
#   > Finished CSV for year2019
# Getting data for state: North Dakota	year: 2020
#   > Finished CSV for year2020
# Getting data for state: North Dakota	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Ohio	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Ohio	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Ohio	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Ohio	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Ohio	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Oklahoma	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Oklahoma	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Oklahoma	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Oklahoma	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Oklahoma	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Oregon	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Oregon	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Oregon	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Oregon	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Oregon	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Pennsylvania	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Pennsylvania	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Pennsylvania	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Pennsylvania	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Pennsylvania	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Rhode Island	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Rhode Island	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Rhode Island	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Rhode Island	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Rhode Island	year: 2021
#   > Finished CSV for year2021
# Getting data for state: South Carolina	year: 2017
#   > Finished CSV for year2017
# Getting data for state: South Carolina	year: 2018
#   > Finished CSV for year2018
# Getting data for state: South Carolina	year: 2019
#   > Finished CSV for year2019
# Getting data for state: South Carolina	year: 2020
#   > Finished CSV for year2020
# Getting data for state: South Carolina	year: 2021
#   > Finished CSV for year2021
# Getting data for state: South Dakota	year: 2017
#   > Finished CSV for year2017
# Getting data for state: South Dakota	year: 2018
#   > Finished CSV for year2018
# Getting data for state: South Dakota	year: 2019
#   > Finished CSV for year2019
# Getting data for state: South Dakota	year: 2020
#   > Finished CSV for year2020
# Getting data for state: South Dakota	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Tennessee	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Tennessee	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Tennessee	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Tennessee	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Tennessee	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Texas	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Texas	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Texas	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Texas	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Texas	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Utah	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Utah	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Utah	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Utah	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Utah	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Vermont	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Vermont	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Vermont	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Vermont	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Vermont	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Virginia	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Virginia	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Virginia	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Virginia	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Virginia	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Washington	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Washington	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Washington	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Washington	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Washington	year: 2021
#   > Finished CSV for year2021
# Getting data for state: West Virginia	year: 2017
#   > Finished CSV for year2017
# Getting data for state: West Virginia	year: 2018
#   > Finished CSV for year2018
# Getting data for state: West Virginia	year: 2019
#   > Finished CSV for year2019
# Getting data for state: West Virginia	year: 2020
#   > Finished CSV for year2020
# Getting data for state: West Virginia	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Wisconsin	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Wisconsin	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Wisconsin	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Wisconsin	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Wisconsin	year: 2021
#   > Finished CSV for year2021
# Getting data for state: Wyoming	year: 2017
#   > Finished CSV for year2017
# Getting data for state: Wyoming	year: 2018
#   > Finished CSV for year2018
# Getting data for state: Wyoming	year: 2019
#   > Finished CSV for year2019
# Getting data for state: Wyoming	year: 2020
#   > Finished CSV for year2020
# Getting data for state: Wyoming	year: 2021
#   > Finished CSV for year2021

# %%
df_state = pd.concat(load_all_states(state_data_dir)).drop("is5", axis=1)

# %%
df_state
# Out:
#            GEO_ID       GEO_TTL  COUNTY  YEAR relevant_naics  \
# 0     0400000US32        Nevada     NaN  2017         324122
# 1     0400000US32        Nevada     NaN  2017            325
# 2     0400000US32        Nevada     NaN  2017             00
# 3     0400000US32        Nevada     NaN  2017          21311
# 4     0400000US32        Nevada     NaN  2017         213111
# ...           ...           ...     ...   ...            ...
# 1271  0400000US38  North Dakota     NaN  2021         813930
# 1272  0400000US38  North Dakota     NaN  2021          81394
# 1273  0400000US38  North Dakota     NaN  2021         813940
# 1274  0400000US38  North Dakota     NaN  2021          81399
# 1275  0400000US38  North Dakota     NaN  2021             99
#
#                                               NAICS_TTL  estab      emp  \
# 0     Asphalt shingle and coating materials manufact...      3        0
# 1                                Chemical manufacturing     80     1359
# 2                                 Total for all sectors  66430  1191625
# 3                         Support activities for mining     69     1595
# 4                            Drilling oil and gas wells      7       29
# ...                                                 ...    ...      ...
# 1271       Labor unions and similar labor organizations     41      254
# 1272                            Political organizations      9       22
# 1273                            Political organizations      9       22
# 1274  Other similar organizations (except business, ...     10      107
# 1275                          Industries not classified     43       56
#
#         payann  state NAICS_Sector
# 0            0     32           32
# 1        77548     32           32
# 2     50960493     32           00
# 3       175576     32           21
# 4         2134     32           21
# ...        ...    ...          ...
# 1271      6176     38           81
# 1272       711     38           81
# 1273       711     38           81
# 1274      2150     38           81
# 1275      1939     38           99
#
# [419244 rows x 11 columns]

# %%
df_state['fips'] = df_state.GEO_ID.apply(lambda GID: GID.split('US')[1])
df_state
# Out:
#            GEO_ID       GEO_TTL  COUNTY  YEAR relevant_naics  \
# 0     0400000US32        Nevada     NaN  2017         324122
# 1     0400000US32        Nevada     NaN  2017            325
# 2     0400000US32        Nevada     NaN  2017             00
# 3     0400000US32        Nevada     NaN  2017          21311
# 4     0400000US32        Nevada     NaN  2017         213111
# ...           ...           ...     ...   ...            ...
# 1271  0400000US38  North Dakota     NaN  2021         813930
# 1272  0400000US38  North Dakota     NaN  2021          81394
# 1273  0400000US38  North Dakota     NaN  2021         813940
# 1274  0400000US38  North Dakota     NaN  2021          81399
# 1275  0400000US38  North Dakota     NaN  2021             99
#
#                                               NAICS_TTL  estab      emp  \
# 0     Asphalt shingle and coating materials manufact...      3        0
# 1                                Chemical manufacturing     80     1359
# 2                                 Total for all sectors  66430  1191625
# 3                         Support activities for mining     69     1595
# 4                            Drilling oil and gas wells      7       29
# ...                                                 ...    ...      ...
# 1271       Labor unions and similar labor organizations     41      254
# 1272                            Political organizations      9       22
# 1273                            Political organizations      9       22
# 1274  Other similar organizations (except business, ...     10      107
# 1275                          Industries not classified     43       56
#
#         payann  state NAICS_Sector fips
# 0            0     32           32   32
# 1        77548     32           32   32
# 2     50960493     32           00   32
# 3       175576     32           21   32
# 4         2134     32           21   32
# ...        ...    ...          ...  ...
# 1271      6176     38           81   38
# 1272       711     38           81   38
# 1273       711     38           81   38
# 1274      2150     38           81   38
# 1275      1939     38           99   38
#
# [419244 rows x 12 columns]

# %%
df_state["COUNTY"] = 0
df_state
# Out:
#            GEO_ID       GEO_TTL  COUNTY  YEAR relevant_naics  \
# 0     0400000US32        Nevada       0  2017         324122
# 1     0400000US32        Nevada       0  2017            325
# 2     0400000US32        Nevada       0  2017             00
# 3     0400000US32        Nevada       0  2017          21311
# 4     0400000US32        Nevada       0  2017         213111
# ...           ...           ...     ...   ...            ...
# 1271  0400000US38  North Dakota       0  2021         813930
# 1272  0400000US38  North Dakota       0  2021          81394
# 1273  0400000US38  North Dakota       0  2021         813940
# 1274  0400000US38  North Dakota       0  2021          81399
# 1275  0400000US38  North Dakota       0  2021             99
#
#                                               NAICS_TTL  estab      emp  \
# 0     Asphalt shingle and coating materials manufact...      3        0
# 1                                Chemical manufacturing     80     1359
# 2                                 Total for all sectors  66430  1191625
# 3                         Support activities for mining     69     1595
# 4                            Drilling oil and gas wells      7       29
# ...                                                 ...    ...      ...
# 1271       Labor unions and similar labor organizations     41      254
# 1272                            Political organizations      9       22
# 1273                            Political organizations      9       22
# 1274  Other similar organizations (except business, ...     10      107
# 1275                          Industries not classified     43       56
#
#         payann  state NAICS_Sector fips
# 0            0     32           32   32
# 1        77548     32           32   32
# 2     50960493     32           00   32
# 3       175576     32           21   32
# 4         2134     32           21   32
# ...        ...    ...          ...  ...
# 1271      6176     38           81   38
# 1272       711     38           81   38
# 1273       711     38           81   38
# 1274      2150     38           81   38
# 1275      1939     38           99   38
#
# [419244 rows x 12 columns]

# %%
naics_str = "relevant_naics"
naics_ttl = "NAICS_TTL"
geo_ttl = "GEO_TTL"

newDF_state = df_state.filter(['fips', 'state', 'COUNTY', 'YEAR' ,geo_ttl, naics_str, naics_ttl,'NAICS_Sector', "estab", "emp", "payann"], axis=1)
newDF_state
# Out:
#      fips  state  COUNTY  YEAR       GEO_TTL relevant_naics  \
# 0      32     32       0  2017        Nevada         324122
# 1      32     32       0  2017        Nevada            325
# 2      32     32       0  2017        Nevada             00
# 3      32     32       0  2017        Nevada          21311
# 4      32     32       0  2017        Nevada         213111
# ...   ...    ...     ...   ...           ...            ...
# 1271   38     38       0  2021  North Dakota         813930
# 1272   38     38       0  2021  North Dakota          81394
# 1273   38     38       0  2021  North Dakota         813940
# 1274   38     38       0  2021  North Dakota          81399
# 1275   38     38       0  2021  North Dakota             99
#
#                                               NAICS_TTL NAICS_Sector  estab  \
# 0     Asphalt shingle and coating materials manufact...           32      3
# 1                                Chemical manufacturing           32     80
# 2                                 Total for all sectors           00  66430
# 3                         Support activities for mining           21     69
# 4                            Drilling oil and gas wells           21      7
# ...                                                 ...          ...    ...
# 1271       Labor unions and similar labor organizations           81     41
# 1272                            Political organizations           81      9
# 1273                            Political organizations           81      9
# 1274  Other similar organizations (except business, ...           81     10
# 1275                          Industries not classified           99     43
#
#           emp    payann
# 0           0         0
# 1        1359     77548
# 2     1191625  50960493
# 3        1595    175576
# 4          29      2134
# ...       ...       ...
# 1271      254      6176
# 1272       22       711
# 1273       22       711
# 1274      107      2150
# 1275       56      1939
#
# [419244 rows x 11 columns]

# %%
df_naics_2_state = naics_level(newDF_state, 2).reset_index(drop=True)
df_naics_3_state = naics_level(newDF_state, 3).reset_index(drop=True)
df_naics_4_state = naics_level(newDF_state, 4).reset_index(drop=True)
df_naics_5_state = naics_level(newDF_state, 5).reset_index(drop=True)
df_naics_6_state = naics_level(newDF_state, 6).reset_index(drop=True)

df_naics_2_state = df_naics_2_state[df_naics_2_state.relevant_naics != '00']
df_naics_3_state = df_naics_3_state[df_naics_3_state.relevant_naics != '00']
df_naics_4_state = df_naics_4_state[df_naics_4_state.relevant_naics != '00']
df_naics_5_state = df_naics_5_state[df_naics_5_state.relevant_naics != '00']
df_naics_6_state = df_naics_6_state[df_naics_6_state.relevant_naics != '00']

# %%
df_naics_2_state
# Out:
#      fips  state  COUNTY  YEAR       GEO_TTL relevant_naics  \
# 1      32     32       0  2017        Nevada             22
# 2      32     32       0  2017        Nevada             11
# 3      32     32       0  2017        Nevada             21
# 4      32     32       0  2017        Nevada             23
# 5      32     32       0  2017        Nevada             42
# ...   ...    ...     ...   ...           ...            ...
# 4495   38     38       0  2021  North Dakota             62
# 4496   38     38       0  2021  North Dakota             71
# 4497   38     38       0  2021  North Dakota             72
# 4498   38     38       0  2021  North Dakota             81
# 4499   38     38       0  2021  North Dakota             99
#
#                                           NAICS_TTL NAICS_Sector  estab  \
# 1                                         Utilities           22    124
# 2        Agriculture, forestry, fishing and hunting           11     55
# 3     Mining, quarrying, and oil and gas extraction           21    184
# 4                                      Construction           23   4979
# 5                                   Wholesale trade           42   3120
# ...                                             ...          ...    ...
# 4495              Health care and social assistance           62   2234
# 4496            Arts, entertainment, and recreation           71    486
# 4497                Accommodation and food services           72   2090
# 4498  Other services (except public administration)           81   2577
# 4499                      Industries not classified           99     43
#
#         emp   payann
# 1      4757   507532
# 2       287    12273
# 3     12935  1251647
# 4     75417  4208010
# 5     37565  2259481
# ...     ...      ...
# 4495  65242  3666950
# 4496   5068   103278
# 4497  30977   654445
# 4498  13674   489660
# 4499     56     1939
#
# [4250 rows x 11 columns]

# %% [markdown]
# ### Comment & uncomment the following code block with CAUTION

# %%
#NOTE: Uncomment if you want to generate the state naics datasets using the state cbp api directly.
#NOTE: If the code blaock is uncommented, make sure that the state naics generation block (above in the nb) using county cbp api is COMMENTED.

states=newDF.state.unique()

a = df_naics_2_state
b = df_naics_4_state
c = df_naics_6_state
for state in states:
    stateName=stateFips.loc[stateFips.FIPS==state,"Postal Code"].values[0]
    print(stateName)

    a1 = a[a.state==state]
    b1 = b[b.state==state]
    c1 = c[c.state==state]

    a1 = a1.drop(["COUNTY", "GEO_TTL", "NAICS_Sector", "NAICS_TTL", "state"],axis=1)
    b1 = b1.drop(["COUNTY", "GEO_TTL", "NAICS_Sector", "NAICS_TTL", "state"],axis=1)
    c1 = c1.drop(["COUNTY", "GEO_TTL", "NAICS_Sector", "NAICS_TTL", "state"],axis=1)


    repo_dir = pathlib.Path().cwd()
    # state_dir = repo_dir.parents[2] / 'us' / 'state-naics-update' / stateName / 'state-naics-api'
    state_dir = repo_dir.parents[2] / 'industries' / 'naics' / 'US' / 'counties-update' / stateName / 'state-naics-api'

    
    if not state_dir.exists():
        state_dir.mkdir(parents=True)

    for year in range(startyear, endyear+1):
        
        ay = a1[a1.YEAR==year]
        by = b1[b1.YEAR==year]
        cy = c1[c1.YEAR==year]

        ay = ay.drop(["YEAR"],axis=1)
        ay = ay.drop(["fips"],axis=1)
        by = by.drop(["YEAR"],axis=1)
        by = by.drop(["fips"],axis=1)
        cy = cy.drop(["YEAR"],axis=1)
        cy = cy.drop(["fips"],axis=1)

        def save_state_data(state, df, naics_level_str):
                
            state = str(state) if len(str(state)) == 2 else "0" + str(state)

            filename = "US-" + stateName + "-" + "census-" + naics_level_str + "-" + str(year) + ".csv"

            curr_df = df.rename(columns={"relevant_naics":"Naics", "estab":"Establishments", "emp":"Employees", "payann":"Payroll"})

            curr_df.to_csv(f"../../../industries/naics/US/counties-update/{stateName}/{filename}", index=False)


        save_state_data(state, ay, "naics2")
        save_state_data(state, by, "naics4")
        save_state_data(state, cy, "naics6")
# Out:
# VA
# KS
# AR
# RI
# DE
# CO
# SD
# NC
# ND
# MI
# ID
# TX
# IA
# MN
# PA
# CA
# AZ
# UT
# NY
# SC
# AK
# LA
# MA
# TN
# GA
# WY
# VT
# WI
# MS
# AL
# OH
# MD
# ME
# MT
# IN
# OR
# NJ
# IL
# CT
# WA
# WV
# NV
# NE
# NH
# KY
# MO
# NM
# OK
# HI
# FL

# %%
# NOTE: Code to remove files and directories from data_raw
# NOTE: Uncomment and run only after you have generated the datasets by running all the abaove code blocks.
# def del_data_raw(bea_data_dir):
    
#     for i in range(startyear,endyear+1):

#         x="_"+str(i)
#         files = [f for f in bea_data_dir.iterdir() if x in f.name]

#         for f in files:
#             os.remove(f)

#     os.rmdir(bea_data_dir)

# del_data_raw(county_data_dir)
# del_data_raw(state_data_dir)
